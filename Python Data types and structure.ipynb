# %% [markdown]
# # Threoy Questiion's

# %% [markdown]
# 1: What are data structure and why are they important?
#   - A data structure is a way of organizing, storing and managing data efficiently so at some point it can be accesed easly.
#   - They are important because:
#    - Efficiency
#    - Data organizing
#    - Problem solving
#
# 2: Explain the difference between mutable and immutable data types with example?
#   - Mutable:
#     - It can be modified
#     - Remains the same after the modification
#     - Ex: List, Dictinory and set
#   - Immutable:
#     - It can't be modified
#     - changes on modification
#     - Ex:- String, Tuple, Integer
#
# 3: What are the main difference between list and tuples in python?
#   - List:-
#     - It is mutable
#     - slower due to dynamic nature
#     - uses more memory
#     - can be modified
#   - Tuples:-
#     - It is immutable
#     - Faster because it is fixed
#     - uses less memory
#     - Cannot be modified after creation
#
# 4: Describe how dictionaries store data?
#   - In python Dictionary is a built in data structure that stores data in a key value pairs. It allows for fastllookups, insertion, and deletion due to its internal implementation using hasing table.
#
# 5: Why might you use a set instead of a list in Python?
#   - List:-
#     - It allows duplication
#     - The order can be maintained
#     - Modificattion can be done
#   - Set:
#     - It stores only unique value
#     - It stores as a unordered collection
#     - Hash table lookup
#
# 6:  What is a string in Python, and how is it different from a list?
#   - String:
#     - Contains only characters
#     - Requires creating a new string
#     - Support indexing and slicing
#   - List:
#     - Can contain any data type
#     - Can modify element in place
#     - Support indexing and slicing
#
# 7: How do tuples ensure data integrity in Python?
#   - Tuples are immutable sequence of element that means when it was created it cannot be changed.
#     - Immutablity prevents accidental changes
#     - Tuples are hasable
#     - Memory efficiency and perfromance
#     - Tuples Prevent Unintended Side Effects in Functions
#
# 8: What is a hash table, and how does it relate to dictionaries in Python?
#   - A hash-table in data structure that stores key value pairs and allows for the fast data retrival.
#   - In python a dictonary is implemented using hash table.This provide fast lookup, insertion, and deletion.
#
# 9: Can lists contain different data types in Python?
#   - Python, list are hetrogenous, meaning they can store multiple data types within the same list.
#   Ex: Integer, Tuple, String, float and dictionary.
#
# 10: Explain why strings are immutable in Python?
#   - A string in python is immutable, menaing it cannot be changed after creation. If you try to change part of a string. Python will raise TypeError.
#
# 11: What advantages do dictionaries offer over lists for certain tasks?
#   - Advantages of dictionary over list are:
#     - Fast lookup and keys
#       - Dictionary allows for constant lookup because they are implemented using hash table.
#     - Key value pair storage:
#       - List are more suitable when you only need to store the sequence of values and they don't support direct association with values.
#     - Flexiable and efficient data modification:
#       - Dictionaries allows for efficient insertion, deletion, and updates for keys.
#     - No duplicates for keys:
#       - Lists allows duplicates, which may cause errors in certain situations.
#
#
# 12: Describe a scenario where using a tuple would be preferable over a list?
#   - Tuples are preferable over list, Tuples are immutable are best used when you need to ensure data integrity, efficiency and constant value.
#
# 13:  How do sets handle duplicate values in Python?
#   - Sets are the collection of unique elements. This means that they automatically discard any duplicat values when elements are added.
#
# 14: How does the “in” keyword work differently for lists and dictionaries?
#   - IN with lists:
#     - When using IN with the list. Python checks if the element exists in the list.
#   - IN with dictionaries:
#     - When using IN with dictionary. Python checks if a key exists in the dictionary.
#
# 15: Can you modify the elements of a tuple? Explain why or why not?
#   - No, you can't modify the element of a tuple once it has been created.This is because tuple are immutable in python meaning you cant edit after creation.
#   Tuple are designed immutable because of several reasons:
#     - Data integrity and security
#     - Performance optimization
#     - Hashability
#
# 16: What is a nested dictionary, and give an example of its use case?
#   - A nested dictionary is a directory that contains another dictionary as a value inside it.This allows you to store data in a hierarchical format.
#   UseCase: Managing construction project data:
#     - A civil engineering firm might need to manage multiple construction projects, each with various attributes like location, budget, and assigned engineers.
#
# 17: Describe the time complexity of accessing elements in a dictionary?
#   - Dictionaries in python are implemented using hash tables, making element high efficiently.
#     - Average case 0(1) Complex Time
#     - Worst case 0(n) Linear Time
#
# 18: In what situations are lists preferred over dictionaries?
#   - While dictionaries are great for quick lookup for keys, list are prefered in situations where ordered,sequential and indexed-based access is required.
#     - Maintaining order:
#       - List contain the order of element, making them ideal for ordered collections.
#     - Iteration and Indexed access:
#       - Lists allow fast, indexed access using integer positions making them more efficient when position-based retrieval is needed.
#
# 19: Why are dictionaries considered unordered, and how does that affect data retrieval?
#   - Dictionaries in python version before 3.7 were considered unordered because they contain the key value pairs using a hash value, which doesn't maintain the insertion order.
#   - Fast key based lookups:-
#     - Instead of searching through elements sequently like list, dictionary uses hash function to directly located a key in constant time.
#   - No Index-Based Access:
#     - Unlike list, you cannot retrive items by position.
#
# 20: Explain the difference between a list and a dictionary in terms of data retrieval?
#   - List Data retrieval:
#     - The data position was access through Index
#     - The lookup speed known through 0(1)
#     - Order preservation maintains insertion order
#     - It allowes the duplicate values
#   - Dictionary Data retrieval:
#     - The data position was access through key value
#     - The lookup speed known through on average 0(1)
#     - Order preservation maintain insertion order
#     - It doesn't allowed the duplicate value

# %% [markdown]
# # Practical Question's

# %%
# 1: Write a code to create a string with your name and print it?
name = "Ronit prasad"
print(name)
# Out:
# Ronit prasad

# %%
# 2: write a code to find the length of the string "Hello world"?
length = "Hello world"
print(len(length))
# Out:
# 11

# %%
# 3: Write a code to slice the first 3 characters from the string "Python Programming"?
text = "Python programming"
sliced_text = text[:3]
print(sliced_text)
# Out:
# Pyt

# %%
# 4: Write a code to convert the string "hello" to uppercase?
name = "hello"
upper_case = name.upper()
print(upper_case)
# Out:
# HELLO

# %%
# 5: Write a code to replace the word "apple" with "orange" in the string "I like apple"?
text = "I like apple"
new_text = text.replace("apple","orange")
print(new_text)
# Out:
# I like orange

# %%
# 6: Write a code to create a list with numbers 1 to 5 and print it?
number = [1,2,3,4,5]
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7: Write a code to append the number 10 to the list [1, 2, 3, 4]?
number = [1,2,3,4]
number.append(10)
print(number)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8: Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]?
number = [1,2,3,4,5]
number.remove(3)
print(number)
# Out:
# [1, 2, 4, 5]

# %%
# 9: Write a code to access the second element in the list ['a', 'b', 'c', 'd']?
letter = ['a','b','c','d']
second_letter = letter[1]
print(second_letter)
# Out:
# b

# %%
# 10: Write a code to reverse the list [10, 20, 30, 40, 50]?
number = [10,20,30,40,50]
number.reverse()
print(number)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11: Write a code to create a tuple with the elements 100, 200, 300 and print it?
number_tuple = (100,200,300)
print(number_tuple)
# Out:
# (100, 200, 300)

# %%
# 12: Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')?
number_tuple = ('red','green','blue','yellow')
access_tuple = number_tuple[1:4]
print(access_tuple)
# Out:
# ('green', 'blue', 'yellow')

# %%
# 13: Write a code to find the minimum number in the tuple (10, 20, 5, 15)?
number = (10,20,5,15)
min_number = min(number)
print(min_number)
# Out:
# 5

# %%
# 14: Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')?
animal = ('dog','cat','rabbit')
animal_idx = animal.index('cat')
print(animal_idx)
# Out:
# 1

# %%
# 15: Write a code to create a tuple containing three different fruits and check if "kiwi" is in it?
fruits = ('Orange','Kiwi','Mango')
check_fruit = 'Kiwi' in fruits
print(check_fruit)
# Out:
# True

# %%
# 16: Write a code to create a set with the elements 'a', 'b', 'c' and print it?
my_set = {'a','b','c'}
print(my_set)
# Out:
# {'c', 'b', 'a'}

# %%
# 17: Write a code to clear all elements from the set {1, 2, 3, 4, 5}?
my_set = {1,2,3,4,5}
clear_set = my_set.clear()
print(clear_set)
# Out:
# None

# %%
# 18: Write a code to remove the element 4 from the set {1, 2, 3, 4}?
my_set = {1,2,3,4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
# 19: Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}?
set1 = {1,2,3}
set2 = {3,4,5}
unionset = set1.union(set2)
print(unionset)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20: Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}?
set1 = {1,2,3}
set2 = {2,3,4}
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {2, 3}

# %%
# 21: Write a code to create a dictionary with the keys "name", "age", and "city", and print it?
my_dict = {
    'name' : "Ronit prasad",
    'age' : 21,
    'city' : "Ahmedabad"
}
print(my_dict)
# Out:
# {'name': 'Ronit prasad', 'age': 21, 'city': 'Ahmedabad'}

# %%
# 22: Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}?
my_dict['country'] = "India"
print(my_dict)
# Out:
# {'name': 'Ronit prasad', 'age': 21, 'city': 'Ahmedabad', 'country': 'India'}

# %%
# 23: Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}?
value = {
    'name': 'Ronit prasad',
    'age': 21
}
name_value = value['name']
print(name_value)
# Out:
# Ronit prasad

# %%
# 24: Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}?
dictionary = {
    'name':"Harrsha",
    'age' : 26,
    'city' : 'India'
}
del dictionary['age']
print(dictionary)
# Out:
# {'name': 'Harrsha', 'city': 'India'}

# %%
# 25: Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}?
check = 'city' in dictionary
print(check)
# Out:
# True

# %%
# 26: Write a code to create a list, a tuple, and a dictionary, and print them all?
list_value = [1,2,3,'Harsh']
tuple_value = ("Harsh",'Harrsha','Rohan')
dict_value = {
    'name' : 'Ronit',
    'age' : 25,
    'city' : 'India'
}
values = (f'This is list {list_value}, this is tuple {tuple_value}, and this is dictionary {dict_value}')
print(values)
# Out:
# This is list [1, 2, 3, 'Harsh'], this is tuple ('Harsh', 'Harrsha', 'Rohan'), and this is dictionary {'name': 'Ronit', 'age': 25, 'city': 'India'}

# %%
# 27: Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)?
import random
random_numbers = [random.randint(1,100) for _ in range(5)]
random_numbers.sort()
print(random_numbers)
# Out:
# [14, 67, 88, 89, 94]

# %%
# 28: Write a code to create a list with strings and print the element at the third index?
list_value = ['Name','Date','Formal','Printer','Values']
list_element = list_value[3]
print(list_element)
# Out:
# Printer

# %%
# 29: Write a code to combine two dictionaries into one and print the result?
dict1 = {
    'name':'Ronit',
    'age': 21,
    'city':'Ahmedabad',
    'country':'India'
}
dict2 = {
    'name':'Harrsha',
    'age':25,
    'city':'Ahmedabad'
}
combined_dict = {**dict1,**dict2}
print(combined_dict)
# Out:
# {'name': 'Harrsha', 'age': 25, 'city': 'Ahmedabad', 'country': 'India'}

# %%
# 30: Write a code to convert a list of strings into a set?
my_list = ['apple','mango','orange','grapes','kiwi']
my_set = set(my_list)
print(my_set)
# Out:
# {'grapes', 'kiwi', 'orange', 'mango', 'apple'}
